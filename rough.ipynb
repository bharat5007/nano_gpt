# %%
import torch
import random

# %%
x = torch.randn(2, 3, 4)
x
# Out:
# tensor([[[ 1.4744,  0.0600, -0.8609,  0.5235],
#          [-1.3147,  0.1336, -0.7295,  0.3293],
#          [ 0.5381, -0.3411, -0.5148, -0.3098]],
#
#         [[ 1.0922, -2.0813, -0.9585, -1.0393],
#          [-1.1278, -0.1916,  0.6662, -0.9143],
#          [-1.9904, -1.5204, -0.9116, -1.0557]]])

# %%
x.view(3,10)
# Out:
# tensor([[ 0.6066, -0.4443,  0.4002, -0.1663,  1.3311,  0.0122,  0.8761, -0.9690,
#          -0.4260,  1.0760],
#         [-0.3513, -0.5783, -0.0486,  0.7539,  0.7355,  2.1542,  0.4605,  1.2659,
#          -0.0042,  1.1674],
#         [ 0.2439,  0.0100,  0.6099, -0.3603, -1.8676,  0.7448,  0.4151, -1.5475,
#           0.8803, -0.1230]])
